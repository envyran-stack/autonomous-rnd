# %% [markdown]
# # State와 Node, Graph
# * LangGraph를 구성하는 핵심 구성요소를 이해합니다

# %% [markdown]
# ---
# * 새로운 Conda 환경에서 실습을 진행하겠습니다.
#
#   아래 명령어로 Python 3.12 환경(day15)을 생성한 후, 해당 환경을 활성화하고 ipykernel을 설치합니다
#
#   ```
#   conda create -n day15 python=3.12
#   conda activate day15
#   conda install ipykernel
#   ```
#
#   이렇게 하면 Jupyter Notebook에서 'day15' 환경을 커널로 사용할 수 있습니다.

# %%
# !pip install python-dotenv langgraph pydantic
# Out:
# Requirement already satisfied: python-dotenv in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: langgraph in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (1.2.9)
# Requirement already satisfied: pydantic in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (2.13.4)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph) (1.4.9)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.10.1)
# Requirement already satisfied: packaging>=23.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (4.14.1)
# Requirement already satisfied: distro>=1.7.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.7.0)

# %%
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = __import__('os').getenv('OPENAI_API_KEY')

WORKDIR = Path.cwd()
ROOT = WORKDIR.parent

print('WORKDIR :', WORKDIR)
# Out:
# WORKDIR : /Users/user/Desktop/cursor 연습/15일차_실습

# %% [markdown]
# ---
# ## State 정의
#
# LangGraph의 **State** = 그래프 전체가 공유하는 메모리.
# `State`는 대표적으로 `TypedDict`와 `BaseModel`을 사용해 정의합니다

# %% [markdown]
# ## `TypedDict`
# 파이썬의 딕셔너리(`{}`)가 특정한 형식을 갖추도록 안내하는 방법
#
# * 개발자 툴(IDE) 등에 표시만 해 줄 뿐, 오류를 일으키는 등 형식을 강제하지는 않습니다
# * 가벼운 개인 프로젝트에 적합하고 여러 명이 개발하는 복잡한 상황에서는 추천하지 않습니다

# %%
from typing_extensions import TypedDict
from datetime import date

class Student(TypedDict):
    name: str
    student_number: int
    birth: date

# %%
student_a: Student = {
    'name': '홍길동',
    'student_number': 2026123123,
    'birth': date(2003, 10, 25)
}

student_a['birth']
# Out:
# datetime.date(2003, 10, 25)

# %%
student_b: Student = {
    'name': 123,
    'student_number': '홍길동'
} # 오류 발생 안함

student_b['name']
# Out:
# 123

# %% [markdown]
# # `pydantic` `BaseModel`
# * pydantic의 `BaseModel`을 활용하면 `TypedDict`보다 강력하게 형식을 강제할 수 있습니다
# * `TypedDict`보다 연산이 조금 더 많지만 다양한 상황에 활용 가능합니다

# %%
from pydantic import BaseModel

class Student(BaseModel):
    name: str
    student_number: int
    birth: date

student_c = Student(name='홍길순', student_number=2026321321, birth=date(2002, 1, 1))

student_c.birth
# Out:
# datetime.date(2002, 1, 1)

# %%
student_d = Student(name=123) # 오류 발생
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 student_d = Student(name=123) # 오류 발생
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 3 validation errors for Student
# name
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type
# student_number
#   Field required [type=missing, input_value={'name': 123}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing
# birth
#   Field required [type=missing, input_value={'name': 123}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing

# %% [markdown]
# ## `BaseModel` 추가 활용법

# %% [markdown]
# ### 1. 어떤 필드가 없어도 오류가 발생하지 않으려면 `Optional`을 사용합니다

# %%
from typing import Optional

class Players(BaseModel):
    player1: str
    player2: Optional[str] = None # str을 입력받지 않으면, None으로 취급

players = Players(player1= '홍길동')

players.player1   #player2가 없어도 error 발생 안함
# Out:
# '홍길동'

# %%
players.player2 = '홍길순'
players
# Out:
# Players(player1='홍길동', player2='홍길순')

# %%
class Players(BaseModel):
    player1: str
    player2: Optional[str] = 'AI' # str을 입력받지 않으면, 'AI'로 취급

players = Players(player1= '홍길동')

players.player2
# Out:
# 'AI'

# %%
players = Players(player1= '홍길동', player2=123) # 오류 발생
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 players = Players(player1= '홍길동', player2=123) # 오류 발생
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for Players
# player2
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type

# %% [markdown]
# ### 2. 어떤 필드의 타입을 여러가지로 지정하려면 `|`을 활용합니다
# * Any 를 사용하면 모든 타입을 허용할 수도 있습니다.

# %%
from typing import Any

class Anything(BaseModel):
    something: int | float | str | None = None
    anything: Optional[Any] = None

a = Anything(something=1)
b = Anything(something=0.5)
c = Anything(something='안녕하세요')
d = Anything(anything = date(1999, 12, 31))

for i in (a, b, c, d):
    print(i.something)

print(d.anything)
# Out:
# 1
# 0.5
# 안녕하세요
# None
# 1999-12-31

# %% [markdown]
# ### 3. `Field` 를 사용해 더 강력한 제약을 넣거나 정보를 추가할 수도 있습니다.
# * `ge`, `le`: 최소/최대값
# * `description`: 해당 값에 대한 설명을 붙일 수 있음
# * `pattern`: 값이 특정 형태를 따르도록 강제

# %%
from pydantic import Field

class SensorInput(BaseModel):
    temperature: int = Field(ge=0, le=100, description='센서 온도(℃)')
    humidity: int = Field(ge=0, le=100)
    operator: str = Field(pattern=r'^Operator\d$')

new_input = SensorInput(temperature=30, humidity=50, operator='Operator3')

new_input
# Out:
# SensorInput(temperature=30, humidity=50, operator='Operator3')

# %%
wrong_input = SensorInput(temperature=-50, humidity=-10, operator='홍길동') # 오류 발생
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 wrong_input = SensorInput(temperature=-50, humidity=-10, operator='홍길동') # 오류 발생
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 3 validation errors for SensorInput
# temperature
#   Input should be greater than or equal to 0 [type=greater_than_equal, input_value=-50, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/greater_than_equal
# humidity
#   Input should be greater than or equal to 0 [type=greater_than_equal, input_value=-10, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/greater_than_equal
# operator
#   String should match pattern '^Operator\d$' [type=string_pattern_mismatch, input_value='홍길동', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_pattern_mismatch

# %% [markdown]
# ### 4. `Literal` 을 사용하면 특정 값을 강제할 수도 있습니다

# %%
from typing import Literal

class Person(BaseModel):
    name: str
    sex: Literal['여', '남']

a = Person(name='홍길동', sex='남')

# %%
b = Person(name='홍길순', sex='여성') # 오류 발생
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 b = Person(name='홍길순', sex='여성') # 오류 발생
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for Person
# sex
#   Input should be '여' or '남' [type=literal_error, input_value='여성', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/literal_error

# %% [markdown]
# ### 5. `try`-`except`문을 활용하면 `ValidationError`를 구조화해 받을 수 있습니다

# %%
from pydantic import ValidationError

class SensorInput(BaseModel):
    temperature: int = Field(ge=0, le=100, description='센서 온도(℃)')

try:
    new_input = SensorInput(temperature=-30)
except ValidationError as e:
    print(e.errors())
# Out:
# [{'type': 'greater_than_equal', 'loc': ('temperature',), 'msg': 'Input should be greater than or equal to 0', 'input': -30, 'ctx': {'ge': 0}, 'url': 'https://errors.pydantic.dev/2.13/v/greater_than_equal'}]

# %%
while True:
    user_input = input("온도 값 입력: ").lower()
    if user_input in ('exit', '종료'):
        break
    try:
        new_input = SensorInput(temperature=user_input)
    except ValidationError as e:
        errors = e.errors()[0]
        key = list( errors['ctx'])[0]
        print(f"오류: 입력하신 값 '{errors['input']}'은 {'최소' if key == 'ge' else '최대'}값 {errors['ctx'][key]} 조건에 어긋납니다.")
        continue

    print("훌륭합니다")
    break

# %% [markdown]
# ## `State` 정의하기
# * LangGraph 에서는 `State`를 중심으로 동작이 수행됩니다.
# * 그래프를 구성하는 모든 노드는 `State`를 통해 정보를 주고받습니다.
# * Langchain에서 멀티턴 대화를 위해 추가한 `history`도 `State`를 통해 관리합니다.

# %%
from typing import Literal

from pydantic import BaseModel, Field


class ChatMessage(BaseModel):
    role: Literal['user', 'assistant', 'system']
    content: str

class AgentState(BaseModel):
    # ── 대화 ──
    chat_history: list[ChatMessage] = Field(default_factory=list) # 맨 처음 생성 시 빈 리스트로 시작
    question: str = ''  # 이번 턴 사용자 입력
    tool_output: Optional[str] = None # 툴 사용 결과

# %% [markdown]
# ---
# ## Node 함수 작성하기

# %% [markdown]
# * Node 함수는 일반적인 python 함수와 동일한 방식으로 작성합니다
# * 모든 Node 함수는 `State`를 인자로 받고, `State`의 변경사항을 Dictionary로 출력합니다.

# %%
def question_node(state: AgentState) -> dict:
    user_question = state.question
    ai_response = f"입력하신 내용은 {user_question} 입니다."

    return {
        'chat_history': state.chat_history + [
            ChatMessage(role='user', content=user_question),
            ChatMessage(role='assistant', content=ai_response)
            ]
        }

# %%
def tool_node(state: AgentState) -> dict:
    return {
        'tool_output': "오늘 날씨는 맑습니다."
    }

# %% [markdown]
# # Node 연결해 그래프 만들기
# * 만든 노드를 `edge`로 연결해 그래프를 만들 수 있습니다.
# * `Graph` 객체에 `node`와 `edge`를 추가하고, `compile`과정을 거치면 그래프를 실행할 수 있습니다.

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(AgentState)

workflow.add_node("question", question_node)
workflow.add_node("tool", tool_node)

workflow.add_edge(START, "question") # 시작하면 question 노드로 간 다음
workflow.add_edge("question", "tool") # tool 노드로 이동하고
workflow.add_edge("tool", END) #실행 종료

app = workflow.compile()

# %%
init_input = AgentState(question="오늘 날씨 어때?") # 초기 시점의 State를 생성하고

final_state = app.invoke(init_input) # Graph에 입력으로 넣어주기

final_state
# Out:
# {'chat_history': [ChatMessage(role='user', content='오늘 날씨 어때?'),
#   ChatMessage(role='assistant', content='입력하신 내용은 오늘 날씨 어때? 입니다.')],
#  'question': '오늘 날씨 어때?',
#  'tool_output': '오늘 날씨는 맑습니다.'}

# %% [markdown]
# ## `stream()` 사용하기
# * `app.stream()` 함수를 사용하면 실시간으로 어떤 노드가 실행되고 값이 어떻게 변하는지 모니터링할 수 있습니다

# %%
init_input = AgentState(question="오늘 날씨 어때?") # 초기 시점의 State를 생성하고

for chunk in app.stream(init_input):
    print(chunk)
# Out:
# {'question': {'chat_history': [ChatMessage(role='user', content='오늘 날씨 어때?'), ChatMessage(role='assistant', content='입력하신 내용은 오늘 날씨 어때? 입니다.')]}}
# {'tool': {'tool_output': '오늘 날씨는 맑습니다.'}}

# %%
from pydantic import BaseModel
from typing import List
from typing import Optional

class ClassState(BaseModel):
    students: list[str]
    boring_count: int
    last_speech: Optional[str] = None

# %%
import time

def speech(state: ClassState) -> dict:
    sp = "안녕하세요. 실습 진행을 맡은 정한솔입니다."
    time.sleep(2)
    print(sp)
    return {
        'last_speech': sp,
        'boring_count': state.boring_count+1
    }

def rest(state: ClassState) -> dict:
    print("휴식 시간입니다.")
    time.sleep(2)
    return {
        'boring_count': 0
    }

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(ClassState)

workflow.add_node("say", speech)
workflow.add_node("rest", rest)

workflow.add_edge(START, "say")
workflow.add_edge("say", "rest")
workflow.add_edge("rest", END)

app = workflow.compile()

# %%
class1 = ClassState(students=['홍길동','홍길순','윤현수'], boring_count=5)

for chunk in app.stream(class1):
    print(chunk)
# Out:
# 안녕하세요. 실습 진행을 맡은 정한솔입니다.
# {'say': {'last_speech': '안녕하세요. 실습 진행을 맡은 정한솔입니다.', 'boring_count': 6}}
# 휴식 시간입니다.
# {'rest': {'boring_count': 0}}
