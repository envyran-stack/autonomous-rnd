# %% [markdown]
# # Conditional Edge

# %% [markdown]
# ## 조건부 Edge(`Conditional Edge`) 사용해 분기 만들기
# * `Conditional Edge`를 이용해 상황에 따라 다른 노드로 연결되도록 구현할 수 있습니다.

# %%
from typing import Literal, Annotated
from pydantic import BaseModel, Field

from langgraph.graph.message import add_messages
from langchain_core.messages import BaseMessage, HumanMessage
import time

class AgentState(BaseModel):
    # Annotated[타입, 메타데이터] -> 해당 변수에 '메타데이터'에 해당하는 특성(기능)을 부여함
    # add_messages -> message에 적용하는 메타데이터, Node에서 history에 추가할 항목만 반환해도 알아서 리스트에 추가해 줌
    chat_history: Annotated[list[BaseMessage], add_messages] = Field(default_factory=list) # 맨 처음 생성 시 빈 리스트로 시작
    last_player: Literal['A', 'B']
    number: int
    end: bool

# %%
def node_A(state: AgentState) -> dict:
    num = state.number
    new_num = num * 2
    time.sleep(1)
    return {
        'chat_history': [HumanMessage(name='A', content=f"숫자를 {num}에서 {new_num}(으)로 바꿈")],
        'number': new_num,
        'last_player': 'A'
    }

# %%
def node_B(state: AgentState) -> dict:
    num = state.number
    new_num = num - 1
    time.sleep(1)
    return {
        'chat_history': [HumanMessage(name='B', content=f"숫자를 {num}에서 {new_num}(으)로 변경")],
        'number': new_num,
        'last_player': 'B'
    }

# %%
def node_judge(state: AgentState) -> dict:
    end = True if state.number > 100 else False
    return {
        'chat_history': [HumanMessage(name='judge', content=f"최종 숫자 {state.number}(으)로 종료합니다" if end else "계속 진행하세요")],
        'end': end
    }

# %%
from langgraph.graph import START, END, StateGraph

workflow = StateGraph(AgentState)

workflow.add_node('A', node_A)
workflow.add_node('B', node_B)
workflow.add_node('judge', node_judge)

workflow.add_edge(START, 'A')
workflow.add_edge('A', 'judge')
workflow.add_edge('B', 'judge')

# %% [markdown]
# ## `route` 만들고 `conditional edge`에 부여하기
# * `route`는 조건에 따라서 달라지는 목적지 `node`명 을 반환하는 함수입니다
# * `workflow.add_conditional_edges`함수에 `route`를 적용하면, route가 반환한 `node`명으로 라우팅됩니다.

# %%
def judge_route(state: AgentState):
    # end가 True면 END로,
    
    if state.end:
        return END
    elif state.last_player == 'B':
        return 'A'
    else:
        return 'B' #node 이름이랑 같아야함.. !

workflow.add_conditional_edges(
    'judge', 
    judge_route
)

# %%
app = workflow.compile()

init_input = AgentState(chat_history=[], last_player='A', number=2, end=False)

for chunk in app.stream(init_input):
    print(chunk)
# Out:
# {'A': {'chat_history': [HumanMessage(content='숫자를 2에서 4(으)로 바꿈', additional_kwargs={}, response_metadata={}, name='A', id='24591a78-2f56-4769-8c62-a4a0a59b9d0b')], 'number': 4, 'last_player': 'A'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='b868528f-b1d4-4352-8376-bbbc51d3bc84')], 'end': False}}
# {'B': {'chat_history': [HumanMessage(content='숫자를 4에서 3(으)로 변경', additional_kwargs={}, response_metadata={}, name='B', id='ce4ec2c9-1b18-4a44-affa-a987deca4bf6')], 'number': 3, 'last_player': 'B'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='02767086-11ec-46f2-aa62-2d42c1bbb34b')], 'end': False}}
# {'A': {'chat_history': [HumanMessage(content='숫자를 3에서 6(으)로 바꿈', additional_kwargs={}, response_metadata={}, name='A', id='efd8af85-f9fd-47fa-8720-62d869471e68')], 'number': 6, 'last_player': 'A'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='721645f9-c66a-4caa-ad45-51e8c5fe0fd0')], 'end': False}}
# {'B': {'chat_history': [HumanMessage(content='숫자를 6에서 5(으)로 변경', additional_kwargs={}, response_metadata={}, name='B', id='1aa3e351-5c7e-4f29-8805-36f964848e93')], 'number': 5, 'last_player': 'B'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='a4e2a7dc-3cb5-434b-becf-fd27bfeffc3c')], 'end': False}}
# {'A': {'chat_history': [HumanMessage(content='숫자를 5에서 10(으)로 바꿈', additional_kwargs={}, response_metadata={}, name='A', id='031acdf6-e642-4fbf-bb06-ca4dfd400a67')], 'number': 10, 'last_player': 'A'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='5378aec7-6c2a-4d05-810b-ee7116f29e50')], 'end': False}}
# {'B': {'chat_history': [HumanMessage(content='숫자를 10에서 9(으)로 변경', additional_kwargs={}, response_metadata={}, name='B', id='403798a1-2a6b-4a4e-b913-8527d681f56d')], 'number': 9, 'last_player': 'B'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='80e359f5-a0e3-4dd4-91d5-6b8a2b8755ac')], 'end': False}}
# {'A': {'chat_history': [HumanMessage(content='숫자를 9에서 18(으)로 바꿈', additional_kwargs={}, response_metadata={}, name='A', id='d91f9bb1-7b2e-4f3f-a22b-f72c9b1e41c3')], 'number': 18, 'last_player': 'A'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='55a9fbac-7d19-4269-a834-99bd210b6e60')], 'end': False}}
# {'B': {'chat_history': [HumanMessage(content='숫자를 18에서 17(으)로 변경', additional_kwargs={}, response_metadata={}, name='B', id='dc9ef5af-f9aa-484a-b3d2-650f552eaf8c')], 'number': 17, 'last_player': 'B'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='7c0f3849-617a-498f-967c-9884d5b164c0')], 'end': False}}
# {'A': {'chat_history': [HumanMessage(content='숫자를 17에서 34(으)로 바꿈', additional_kwargs={}, response_metadata={}, name='A', id='9617c39d-4da8-40f1-bdbe-001da82bb745')], 'number': 34, 'last_player': 'A'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='380697eb-ff1e-4080-9e18-335ede2b8496')], 'end': False}}
# {'B': {'chat_history': [HumanMessage(content='숫자를 34에서 33(으)로 변경', additional_kwargs={}, response_metadata={}, name='B', id='f9f854fb-9fc0-496e-a860-47e2d6efaeac')], 'number': 33, 'last_player': 'B'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='a9481571-6d36-4940-838b-7a9681702ce1')], 'end': False}}
# {'A': {'chat_history': [HumanMessage(content='숫자를 33에서 66(으)로 바꿈', additional_kwargs={}, response_metadata={}, name='A', id='1bd8044f-7442-4026-b369-2e94bb224544')], 'number': 66, 'last_player': 'A'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='39867f83-bc8b-48f3-bda2-469e0b792595')], 'end': False}}
# {'B': {'chat_history': [HumanMessage(content='숫자를 66에서 65(으)로 변경', additional_kwargs={}, response_metadata={}, name='B', id='9ba92861-f760-46d2-b47e-85558fa3bf4b')], 'number': 65, 'last_player': 'B'}}
# {'judge': {'chat_history': [HumanMessage(content='계속 진행하세요', additional_kwargs={}, response_metadata={}, name='judge', id='d506d009-9ee0-4a69-97be-466d85e23c27')], 'end': False}}
# {'A': {'chat_history': [HumanMessage(content='숫자를 65에서 130(으)로 바꿈', additional_kwargs={}, response_metadata={}, name='A', id='c4a64bf1-5300-46da-97f0-bfdd0be0b0f5')], 'number': 130, 'last_player': 'A'}}
# {'judge': {'chat_history': [HumanMessage(content='최종 숫자 130(으)로 종료합니다', additional_kwargs={}, response_metadata={}, name='judge', id='cc50cb98-fdad-4697-998e-8fffaa1fa035')], 'end': True}}

# %% [markdown]
# ## 토마토 게임 만들기
# * ai와 토마토 게임을 진행할 수 있는 LangGraph 기반 게임을 만들어 봅시다
# * 규칙: 두 명이 번갈아가면서 '토마토'를 한글자씩 말합니다. 올바르게 말하지 못하면 패배합니다.

# %%
from pydantic import BaseModel, Field
from typing import Literal, Optional

WORD = '토마토'

class TomatoGameState(BaseModel):
    next_player: Literal['user', 'ai']
    player_input: Optional[str] = None
    last_player: Optional[Literal['user', 'ai']] = None
    index: int = 0
    end : bool = False
    winner: Optional[str] = None
    message: str = ''

# %%
def user_node(state: TomatoGameState) -> dict:
    user_input = input("당신의 대답: ").strip()
    print(f"\n[당신 차례] : {user_input}")
    return {
        'player_input': user_input,
        'last_player': 'user',
        'next_player': 'ai',
    }

def ai_node(state: TomatoGameState) -> dict:
    ai_input = WORD[state.index]
    print(f"\n[AI 차례] : {ai_input}")
    return {
        'player_input': ai_input,
        'last_player': 'ai',
        'next_player': 'user',
    }

def judge_node(state: TomatoGameState) -> dict:
    expected = WORD[state.index]
    if state.player_input == expected:
        return {
            'message': f"정답입니다! {expected}를 말하셨습니다.",
            'index': state.index + 1,
        }
    else:
# Out:
#   Cell In[50], line 26
#     else:
#           ^
# SyntaxError: incomplete input

# %%
TARGET = ['토','마','토']

def node_judge(state: TomatoGameState) -> dict:
    answer = TARGET[state.index]
    said = state.player_input
    return {
        'end': end
    }

# %%
from langgraph.graph import START, END, StateGraph

workflow = StateGraph(TomatoGameState)

workflow.add_node('user', user_node)
workflow.add_node('ai', ai_node)
workflow.add_node('judge', judge_node)

workflow.add_edge(START, 'user')
workflow.add_edge('user', 'judge')
workflow.add_edge('ai', 'judge')

# %%
def judge_route(state: TomatoGameState):
    # end가 True면 END로,
    
    if state.end:
        return END
    elif state.next_player == 'user':
        return 'user'
    else:
        return 'ai' #node 이름이랑 같아야함.. !

workflow.add_conditional_edges(
    'judge', 
    judge_route
)

# %%
app = workflow.compile()

init_input = TomatoGameState(next_player='user', index=0, end=False)

for chunk in app.stream(init_input):
    print(chunk)
# Out:
# {'user': {'player_input': '토', 'last_player': 'user', 'next_player': 'ai'}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 5
#       1 app = workflow.compile()
#       2
#       3 init_input = TomatoGameState(next_player='user', index=0, end=False)
#       4
# ----> 5 for chunk in app.stream(init_input):
#       6     print(chunk)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/pregel/main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# Cell In[38], line 19, in judge_node(state)
#      18 def judge_node(state: TomatoGameState) -> dict:
# ---> 19     end = True if state.start else False
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/pydantic/main.py:1042, in BaseModel.__getattr__(self, item)
#    1039     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1040 else:
#    1041     # this is the current error
# -> 1042     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'TomatoGameState' object has no attribute 'start'
# During task with name 'judge' and id 'dd292efa-cc60-aa62-9648-6b977d4a6920'

# %% [markdown]
# ### 팬아웃(Fan-Out) 구현하기
# * 하나의 노드에서 여러 노드로 갈라지고(팬아웃) 다시 한 노드로 흐름을 모을 (팬인) 수 있습니다

# %%
from pydantic import BaseModel
from typing import Optional, Any

class FanOutState(BaseModel):
    value1: Optional[Any] = None
    value2: Optional[Any] = None

# %%
import time

def node_A(state: FanOutState) -> dict:
    print("A 노드에서 출발합니다.")
    return {"from_node": "A"}

def node_B(state: FanOutState) -> dict:
    for i in range(1, 4):
        print(f"B 노드 실행 중... ({i}/3)")
        time.sleep(1)
    return {"value1": state.value1 + 1}

def node_C(state: FanOutState) -> dict:
    for i in range(1, 4):
        print(f"C 노드 실행 중... ({i}/3)")
        time.sleep(1)
    return {"value2": state.value2 + 1}

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(FanOutState)

workflow.add_node('A', node_A)
workflow.add_node('B', node_B)
workflow.add_node('C', node_C)

workflow.add_edge(START, 'A')
workflow.add_edge('A', 'B')
workflow.add_edge('A', 'C')

app = workflow.compile()

# %%
init_state = FanOutState(value1=0, value2=0)
result = app.invoke(init_state)
result
# Out:
# A 노드에서 출발합니다.
# B 노드 실행 중... (1/3)
# C 노드 실행 중... (1/3)
# B 노드 실행 중... (2/3)C 노드 실행 중... (2/3)
#
# C 노드 실행 중... (3/3)
# B 노드 실행 중... (3/3)
# {'value1': 1, 'value2': 1}

# %% [markdown]
# ## 팬인(Fan-In) 구현하기
# * `add_edge` 함수의 출발점은 여러 노드의 배열도 입력받을 수 있습니다.

# %%
def node_D(state: FanOutState):
    for i in range(1, 4):
        print(f"D 노드 실행 중... ({i}/3)")
        time.sleep(1)
    return {"value2": state.value1 + 1}

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(FanOutState)

workflow.add_node('A', node_A)
workflow.add_node('B', node_B)
workflow.add_node('C', node_C)
workflow.add_node('D', node_D)

workflow.add_edge(START, 'A')
workflow.add_edge('A', 'B')
workflow.add_edge('A', 'C')
workflow.add_edge(['B', 'C'], 'D')
workflow.add_edge('D', END)

app = workflow.compile()

# %%
init_state = FanOutState(value1=0, value2=0)
result = app.invoke(init_state)
result
# Out:
# A 노드에서 출발합니다.
# B 노드 실행 중... (1/3)
# C 노드 실행 중... (1/3)
# C 노드 실행 중... (2/3)
# B 노드 실행 중... (2/3)
# C 노드 실행 중... (3/3)
# B 노드 실행 중... (3/3)
# D 노드 실행 중... (1/3)
# D 노드 실행 중... (2/3)
# D 노드 실행 중... (3/3)
# {'value1': 1, 'value2': 2}

# %% [markdown]
# ### Q. 팬인 시 노드 종료 시점이 다르다면?

# %%
import time

def node_A(state: FanOutState) -> dict:
    print("A 노드에서 출발합니다.")
    return {"from_node": "A"}

def node_B(state: FanOutState) -> dict: # 두 노드의 실행 시간을 다르게 하고 결과를 확인해보세요.
    for i in range(1, 4):
        print(f"B 노드 실행 중... ({i}/3)")
        time.sleep(1)
    return {"value1": state.value1 + 100}

def node_C(state: FanOutState) -> dict:
    for i in range(1, 4):
        print(f"C 노드 실행 중... ({i}/3)")
        time.sleep(4)
    return {"value2": state.value2 + 1}

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(FanOutState)

workflow.add_node('A', node_A)
workflow.add_node('B', node_B)
workflow.add_node('C', node_C)
workflow.add_node('D', node_D)

workflow.add_edge(START, 'A')
workflow.add_edge('A', 'B')
workflow.add_edge('A', 'C')
workflow.add_edge(['B', 'C'], 'D')
workflow.add_edge('D', END)

app = workflow.compile()

# %%
init_state = FanOutState(value1=0, value2=0)
result = app.invoke(init_state)
result
# Out:
# A 노드에서 출발합니다.
# B 노드 실행 중... (1/3)
# C 노드 실행 중... (1/3)
# B 노드 실행 중... (2/3)
# B 노드 실행 중... (3/3)
# C 노드 실행 중... (2/3)
# C 노드 실행 중... (3/3)
# D 노드 실행 중... (1/3)
# D 노드 실행 중... (2/3)
# D 노드 실행 중... (3/3)
# {'value1': 100, 'value2': 101}

# %% [markdown]
# # `Reducer` 활용하기

# %%
import time

def node_A(state: FanOutState) -> dict:
    print("A 노드에서 출발합니다.")
    return {"from_node": "A"}

def node_B(state: FanOutState) -> dict:
    for i in range(1, 6):
        print(f"B 노드 실행 중... ({i}/5)")
        time.sleep(1)
    return {"value1": state.value1 + 1}

def node_C(state: FanOutState) -> dict: # B, C 노드 모두에서 value1 값을 변경하는 경우
    for i in range(1, 4):
        print(f"C 노드 실행 중... ({i}/3)")
        time.sleep(1)
    return {"value1": state.value1 + 1}

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(FanOutState)

workflow.add_node('A', node_A)
workflow.add_node('B', node_B)
workflow.add_node('C', node_C)
workflow.add_node('D', node_D)

workflow.add_edge(START, 'A')
workflow.add_edge('A', 'B')
workflow.add_edge('A', 'C')
workflow.add_edge(['B', 'C'], 'D')
workflow.add_edge('D', END)

app = workflow.compile()

# %%
init_state = FanOutState(value1=0, value2=0)
result = app.invoke(init_state) # reducer가 없으면 오류 발생
result
# Out:
# A 노드에서 출발합니다.
# B 노드 실행 중... (1/5)
# C 노드 실행 중... (1/3)
# B 노드 실행 중... (2/5)C 노드 실행 중... (2/3)
#
# C 노드 실행 중... (3/3)B 노드 실행 중... (3/5)
#
# B 노드 실행 중... (4/5)
# B 노드 실행 중... (5/5)
# ---------------------------------------------------------------------------
# InvalidUpdateError                        Traceback (most recent call last)
# Cell In[73], line 2
#       1 init_state = FanOutState(value1=0, value2=0)
# ----> 2 result = app.invoke(init_state) # reducer가 없으면 오류 발생
#       3 result
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/pregel/main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/pregel/main.py:2984, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    (...)   2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
# -> 2984 loop.after_tick()
#    2985 emit_graph_lifecycle_events(loop)
#    2986 # wait for checkpoint
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/pregel/_loop.py:692, in PregelLoop.after_tick(self)
#     686 self._delta_channels_with_overwrite.update(
#     687     ch
#     688     for ch, v in writes
#     689     if isinstance(self.specs.get(ch), DeltaChannel) and _get_overwrite(v)[0]
#     690 )
#     691 # all tasks have finished
# --> 692 self.updated_channels = apply_writes(
#     693     self.checkpoint,
#     694     self.channels,
#     695     self.tasks.values(),
#     696     self.checkpointer_get_next_version,
#     697     self.trigger_to_nodes,
#     698 )
#     699 # produce values output
#     700 if not self.updated_channels.isdisjoint(
#     701     (self.output_keys,)
#     702     if isinstance(self.output_keys, str)
#     703     else self.output_keys
#     704 ):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/pregel/_algo.py:319, in apply_writes(checkpoint, channels, tasks, get_next_version, trigger_to_nodes)
#     317 for chan, vals in pending_writes_by_channel.items():
#     318     if chan in channels:
# --> 319         if channels[chan].update(vals) and next_version is not None:
#     320             checkpoint["channel_versions"][chan] = next_version
#     321             # unavailable channels can't trigger tasks, so don't add them
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/day15/lib/python3.12/site-packages/langgraph/channels/last_value.py:64, in LastValue.update(self, values)
#      59 if len(values) != 1:
#      60     msg = create_error_message(
#      61         message=f"At key '{self.key}': Can receive only one value per step. Use an Annotated key to handle multiple values.",
#      62         error_code=ErrorCode.INVALID_CONCURRENT_GRAPH_UPDATE,
#      63     )
# ---> 64     raise InvalidUpdateError(msg)
#      66 self.value = values[-1]
#      67 return True
#
# InvalidUpdateError: At key 'value1': Can receive only one value per step. Use an Annotated key to handle multiple values.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE

# %%
from typing import Annotated

def numberAddReducer(left: int, right: int) -> int: # left: 기존 State, right: return 받은 state
    return left + right # return 받은 값으로 대체하지 않고, 기존 값에 return 받은 값을 더함

class ReducerState(BaseModel):
    value1: Annotated[Optional[Any], numberAddReducer] = None
    value2: Optional[Any] = None

# %%
def node_B(state: ReducerState) -> dict: # state 정의도 모두 변경
    for i in range(1, 6):
        print(f"B 노드 실행 중... ({i}/5)")
        time.sleep(1)
    return {"value1": 1} # 새로 더해줄 값만 반환하면 됨

def node_C(state: ReducerState) -> dict: # B, C 노드 모두에서 value1 값을 변경하는 경우
    for i in range(1, 4):
        print(f"C 노드 실행 중... ({i}/3)")
        time.sleep(1)
    return {"value1": 1}

def node_D(state: ReducerState):
    for i in range(1, 4):
        print(f"D 노드 실행 중... ({i}/3)")
        time.sleep(1)
    return {"value2": state.value2 + 1}

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(ReducerState)

workflow.add_node('A', node_A)
workflow.add_node('B', node_B)
workflow.add_node('C', node_C)
workflow.add_node('D', node_D)

workflow.add_edge(START, 'A')
workflow.add_edge('A', 'B')
workflow.add_edge('A', 'C')
workflow.add_edge(['B', 'C'], 'D')
workflow.add_edge('D', END)

app = workflow.compile()

# %%
init_state = ReducerState(value1=0, value2=0)
result = app.invoke(init_state) # reducer가 없으면 오류 발생
result
# Out:
# A 노드에서 출발합니다.
# B 노드 실행 중... (1/5)
# C 노드 실행 중... (1/3)
# B 노드 실행 중... (2/5)C 노드 실행 중... (2/3)
#
# B 노드 실행 중... (3/5)C 노드 실행 중... (3/3)
#
# B 노드 실행 중... (4/5)
# B 노드 실행 중... (5/5)
# D 노드 실행 중... (1/3)
# D 노드 실행 중... (2/3)
# D 노드 실행 중... (3/3)
# {'value1': 2, 'value2': 1}

# %% [markdown]
# ### 동적 팬아웃 구현하기
# * `Conditional Edge`를 이용하면 Fan-Out을 동적으로 설정할 수 있습니다
# * Fan-Out을 설정하려면, 목적지 노드 이름을 리스트로 모두 전달하면 됩니다.

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(ReducerState)

workflow.add_node('A', node_A)
workflow.add_node('B', node_B)
workflow.add_node('C', node_C)
workflow.add_node('D', node_D)

workflow.add_edge(START, 'A')

def fanout_router(state: ReducerState):
    if state.value2 > 0:
        return 'B'
    else:
        return ['B', 'C']
    
workflow.add_conditional_edges('A', fanout_router)

workflow.add_edge(['B', 'C'], 'D')

def end_router(state: ReducerState):
    if state.value1 > 2:
        return END
    else:
        return 'A'

workflow.add_conditional_edges('D', end_router)


app = workflow.compile()

# %%
init_state = ReducerState(value1=0, value2=0)
result = app.invoke(init_state)
result
# Out:
# A 노드에서 출발합니다.
# B 노드 실행 중... (1/5)
# C 노드 실행 중... (1/3)
# B 노드 실행 중... (2/5)
# C 노드 실행 중... (2/3)
# B 노드 실행 중... (3/5)
# C 노드 실행 중... (3/3)
# B 노드 실행 중... (4/5)
# B 노드 실행 중... (5/5)
# D 노드 실행 중... (1/3)
# D 노드 실행 중... (2/3)
# D 노드 실행 중... (3/3)
# A 노드에서 출발합니다.
# B 노드 실행 중... (1/5)
# B 노드 실행 중... (2/5)
# B 노드 실행 중... (3/5)
# B 노드 실행 중... (4/5)
# B 노드 실행 중... (5/5)
# {'value1': 3, 'value2': 1}

# %% [markdown]
# ### 라우팅 심화 문제
# * Fan-Out과 Reducing, 조건부 Edge를 적극적으로 활용해 음식점 운영을 최적화해봅시다 (괄호 안의 숫자는 소요시간(초))
# ```
# burger: patty(5), bun(3) 각각 필요 -> burgerSet(2)
# fries: fry(3) -> friesSet(1)
# beverage: beverage(2)
#
# 세 가지가 모두 준비되면 종료
# ```

# %%
from pydantic import BaseModel
from typing import List, Annotated, Literal, Optional

def menuReducer(left:List[str], right:List[str]) -> List[str]:
    return left + right

class RestaurantState(BaseModel):
    menu_ordered: List[Literal['burger', 'fries', 'beverage']]
    menu_complete: Annotated[Optional[List[Literal['burger', 'fries', 'beverage']]], menuReducer] = []

# %%
import time

# 각종 그래프 노드 실행 및 상태 갱신 통합: 반환값으로 state의 menu_complete를 적절히 업데이트하도록 구성
def g_burger_start(state: RestaurantState) -> dict:
    print("버거 준비 시작")
    return {}

def g_fries_start(state: RestaurantState) -> dict:
    print("감자튀김 준비 시작")
    return {}

def g_patty(state: RestaurantState) -> dict:
    print("패티 조리 시작")
    time.sleep(5)
    print("패티 조리 완료")
    return {}

def g_bun(state: RestaurantState) -> dict:
    print("번 조리 시작")
    time.sleep(3)
    print("번 조리 완료")
    return {}

def g_burger_set(state: RestaurantState) -> dict:
    print("버거 세트 조립 시작")
    time.sleep(2)
    print("버거 세트 조립 완료")
    return {}

def g_burger_complete(state: RestaurantState) -> dict:
    print("버거 완성")
    return {'menu_complete': ['burger']}

def g_fry(state: RestaurantState) -> dict:
    print("감자튀김 조리 시작")
    time.sleep(3)
    print("감자튀김 조리 완료")
    return {}

def g_fries_set(state: RestaurantState) -> dict:
    print("감자튀김 세트 준비 시작")
    time.sleep(1)
    print("감자튀김 세트 준비 완료")
    return {}

def g_fries_complete(state: RestaurantState) -> dict:
    print("감자튀김 완성")
    return {'menu_complete': ['fries']}

def g_beverage(state: RestaurantState) -> dict:
    print("음료 준비 시작")
    time.sleep(2)
    print("음료 준비 완료")
    return {'menu_complete': ['beverage']}

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(RestaurantState)

# ── 노드 등록 ──
workflow.add_node('burger_start', g_burger_start)
workflow.add_node('patty', g_patty)
workflow.add_node('bun', g_bun)
workflow.add_node('burger_set', g_burger_set)
workflow.add_node('burger_complete', g_burger_complete)

workflow.add_node('fries_start', g_fries_start)
workflow.add_node('fry', g_fry)
workflow.add_node('fries_set', g_fries_set)
workflow.add_node('fries_complete', g_fries_complete)

workflow.add_node('beverage', g_beverage)


# ── 1) 시작: 주문 메뉴만큼 Fan-Out ──
def start_router(state: RestaurantState):
    """주문한 메뉴 시작 노드 이름을 리스트로 반환 → 동시에 출발"""
    mapping = {
        'burger': 'burger_start',
        'fries': 'fries_start',
        'beverage': 'beverage',
    }
    return [mapping[m] for m in state.menu_ordered]

workflow.add_conditional_edges(START, start_router)


# ── 2) 버거 라인 ──
# burger_start → patty, bun (병렬)
workflow.add_edge('burger_start', 'patty')
workflow.add_edge('burger_start', 'bun')
# patty + bun 둘 다 끝나면 조립 (Fan-In)
workflow.add_edge(['patty', 'bun'], 'burger_set')
workflow.add_edge('burger_set', 'burger_complete')


# ── 3) 감자튀김 라인 ──
workflow.add_edge('fries_start', 'fry')
workflow.add_edge('fry', 'fries_set')
workflow.add_edge('fries_set', 'fries_complete')


# ── 4) 음료는 beverage 노드 하나로 끝 ──


# ── 5) 세 메뉴 완성되면 종료 (Fan-In) ──
# ※ 아래 종료 연결은 세 메뉴를 모두 주문했을 때 기준
workflow.add_edge(
    ['burger_complete', 'fries_complete', 'beverage'],
    END,
)

app = workflow.compile()

# %%
init = RestaurantState(
    menu_ordered=['burger', 'fries', 'beverage'],
    menu_complete=[],
)

result = app.invoke(init)
print(result)
# menu_complete 안에 burger, fries, beverage가 들어있으면 성공
# Out:
# 음료 준비 시작
# 버거 준비 시작
# 감자튀김 준비 시작
# 음료 준비 완료
# 번 조리 시작
# 감자튀김 조리 시작
# 패티 조리 시작
# 감자튀김 조리 완료번 조리 완료
#
# 패티 조리 완료
# 버거 세트 조립 시작
# 감자튀김 세트 준비 시작
# 감자튀김 세트 준비 완료
# 버거 세트 조립 완료
# 버거 완성
# 감자튀김 완성
# {'menu_ordered': ['burger', 'fries', 'beverage'], 'menu_complete': ['beverage', 'burger', 'fries']}
